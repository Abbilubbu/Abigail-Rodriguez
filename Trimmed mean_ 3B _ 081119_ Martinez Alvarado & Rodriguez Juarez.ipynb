# %% [markdown]
# # Trimmed mean
#
# #### Martinez Alvarado Carolina & Rodriguez Juarez
#
# ** Develop a program that calculates trimmed mean. The usser have to introduce the set of data and the percentage they want to use.

# %%
a = 0
b = 0
c = 0
C = []
i = 0
n= 0 
sum_x = 0
k = []
n3 = n-1
T = []


Trimmed_mean = []

a = int(input("Hello! How much percentage you want to put?: \n>"))
print("\nVery well!..., so now:")

  
while i == 0:
    
    for k in range(0,1):
        x = float(input("\nIntroduce a value (When you finish press >0.0<)\n**The low limit are 12 values!\n>"))
        n += 1
        A = a / 100
        B = A * (n-2)
        C.append(x)
        CC = sorted(C)

        def rounda(B):        #Para redondear el programa toma como <.7, 1.7, 2.7 ect...> para pasar 
            dec = B - int(B)  #al siguiente entero.
            rst = int(B) if dec < 0.5 else int(B)+1
            return rst
        
    if x == 0.0:
        
        if n <= 11: #No se puede tomar por debajo de este limite ya que 10% no lo decteta hasta este rango
            print("\nYou need more than 11 values! ='d")
            i = 1
            
        if n >= 12:
            D = rounda(B)
            G = rounda(B) + 1
            C_1 = CC[G:-D]
            n1 = (n - 2) - G - 1 #N no sirve para lista impares, solo pares
            n2 = n - 1

            def sumlist(C_1):
                lasuma = 0
                for p in C_1:
                    lasuma = lasuma + p
                return lasuma

            Trimed_mean = sumlist(C_1) / n1

            print(f"\n*The {a}% of {n2} numbers is:\n{D}")

            print(f"\n*The list of number to count:\n{C_1}")

            print(f"\n*Operation:\n(1/{n1})({sumlist(C_1)})")

            print("\n*Your trimmed mean is:\n", Trimed_mean)
            
            i = 1
# Out:
# Hello! How much percentage you want to put?:
# >20
#
# Very well!..., so now:
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >5
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >6
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >8
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >56
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >21
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >34
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >26
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >9
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >85
#
# Introduce a value (When you finish press >0.0<)
# **The low limit are 12 values!
# >45
#
# ...
